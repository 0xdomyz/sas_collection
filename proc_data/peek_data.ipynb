# %%
import saspy
sas = saspy.SASsession(cfgname='oda', )

def run(code):
    sas.submitLST(code)
# Out:
# SAS Connection established. Subprocess id is 14268

# %%
libref = 'SASHELP'
tbl = "cars"
tbl_name = f"{libref}.{tbl}"

# %%
cols = """
cylinders
drivetrain
enginesize
horsepower
length
mpg_city
mpg_highway
msrp
make
model
origin
type
weight
wheelbase
"""

cols = cols.strip().split('\n')
cols
# Out:
# ['cylinders',
#  'drivetrain',
#  'enginesize',
#  'horsepower',
#  'length',
#  'mpg_city',
#  'mpg_highway',
#  'msrp',
#  'make',
#  'model',
#  'origin',
#  'type',
#  'weight',
#  'wheelbase']

# %%
sdf = sas.sasdata(
    tbl,
    libref,
    dsopts={
        'keep' : ' '.join(cols),
    }
)
df = sdf.head()
df.columns = df.columns.str.lower()

df
# Out:
#     make           model   type origin drivetrain     msrp  enginesize  \
# 0  Acura             MDX    SUV   Asia        All  36945.0         3.5
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  23820.0         2.0
# 2  Acura         TSX 4dr  Sedan   Asia      Front  26990.0         2.4
# 3  Acura          TL 4dr  Sedan   Asia      Front  33195.0         3.2
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  43755.0         3.5
#
#    cylinders  horsepower  mpg_city  mpg_highway  weight  wheelbase  length
# 0        6.0       265.0      17.0         23.0  4451.0      106.0   189.0
# 1        4.0       200.0      24.0         31.0  2778.0      101.0   172.0
# 2        4.0       200.0      22.0         29.0  3230.0      105.0   183.0
# 3        6.0       270.0      20.0         28.0  3575.0      108.0   186.0
# 4        6.0       225.0      18.0         24.0  3880.0      115.0   197.0

# %%
df.iloc[0,:]
# Out:
# make             Acura
# model              MDX
# type               SUV
# origin            Asia
# drivetrain         All
# msrp           36945.0
# enginesize         3.5
# cylinders          6.0
# horsepower       265.0
# mpg_city          17.0
# mpg_highway       23.0
# weight          4451.0
# wheelbase        106.0
# length           189.0
# Name: 0, dtype: object

# %%
sdf = sas.sasdata(tbl, libref=libref)
df = sdf.columnInfo()
df = df[df['Variable'].str.lower().isin(cols)]
df
# Out:
#           Member   Num     Variable  Type   Len    Pos    Format  \
# 0   SASHELP.CARS   9.0    Cylinders   Num   8.0   24.0       NaN
# 1   SASHELP.CARS   5.0   DriveTrain  Char   5.0  147.0       NaN
# 2   SASHELP.CARS   8.0   EngineSize   Num   8.0   16.0       NaN
# 3   SASHELP.CARS  10.0   Horsepower   Num   8.0   32.0       NaN
# 5   SASHELP.CARS  15.0       Length   Num   8.0   72.0       NaN
# 6   SASHELP.CARS  11.0     MPG_City   Num   8.0   40.0       NaN
# 7   SASHELP.CARS  12.0  MPG_Highway   Num   8.0   48.0       NaN
# 8   SASHELP.CARS   6.0         MSRP   Num   8.0    0.0  DOLLAR8.
# 9   SASHELP.CARS   1.0         Make  Char  13.0   80.0       NaN
# 10  SASHELP.CARS   2.0        Model  Char  40.0   93.0       NaN
# 11  SASHELP.CARS   4.0       Origin  Char   6.0  141.0       NaN
# 12  SASHELP.CARS   3.0         Type  Char   8.0  133.0       NaN
# 13  SASHELP.CARS  13.0       Weight   Num   8.0   56.0       NaN
# ...

# %%
code = f"""
proc sql;
    create view {tbl}_sub as
    select {', '.join(cols)}
    from {tbl_name}
    where 1=1;
quit;

PROC MEANS DATA={tbl}_sub;
RUN;
"""
run(code)
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
col = "origin"

code = f"""
PROC freq DATA={tbl}_sub;
tables {col};
RUN;
"""
run(code)
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
col = "enginesize"

code = f"""
PROC UNIVARIATE DATA={tbl}_sub;
VAR {col};
RUN;
"""
run(code)
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
col = "type"
msmt = "msrp"

code = f"""
PROC SQL;
    SELECT {col},
           COUNT(*) AS count,
           ROUND(SUM({msmt})/1000000, 0.01) AS {msmt}_mil
    FROM {tbl}_sub
    GROUP BY 1
    order by 2 desc
    ;
QUIT;
"""
run(code)
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...
