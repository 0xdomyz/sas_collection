# %%
import saspy

sas = saspy.SASsession(cfgname="oda")
# Out:
# SAS Connection established. Subprocess id is 9908

# %% [markdown]
# ### The sas session class

# %%
sas
# Out:
# Access Method         = IOM
# SAS Config name       = oda
# SAS Config file       = C:\Users\yzdom/.config/saspy\sascfg_personal.py
# WORK Path             = /saswork/SAS_work3AA0000035FE_odaws01-apse1-2.oda.sas.com/SAS_work5E87000035FE_odaws01-apse1-2.oda.sas.com/
# SAS Version           = 9.04.01M7P08062020
# SASPy Version         = 5.6.0
# Teach me SAS          = False
# Batch                 = False
# Results               = Pandas
# SAS Session Encoding  = utf-8
# Python Encoding value = utf-8
# SAS process Pid value = 13822

# %%
for i in dir(sas.sascfg):
    if not i.startswith("_"):
        print(i, getattr(sas.sascfg, i))
# Out:
# DISPLAY <function display at 0x00000215CC860FE0>
# DOTCONFIG ~/.config/saspy/
# HTML <class 'IPython.core.display.HTML'>
# SAScfg <module 'sascfg_personal' from 'C:\\Users\\yzdom/.config/saspy\\sascfg_personal.py'>
# autoexec None
# bcv 5006000
# cfgopts {'lock_down': False, 'verbose': True, 'prompt': True}
# colorLOG False
# curver 5006000
# display jupyter
# mode IOM
# name oda
# odsstyle Plateau
# origin C:\Users\yzdom/.config/saspy\sascfg_personal.py
# pandas None
# prompt True
# results None
# valid True

# %%
methods = []
for i in sas.__dir__():
    if not i.startswith("_"):
        methods.append(i)

methods.sort()

print(f"{len(methods) = }")

import math


def print_dir_style(lst, num_columns):
    max_len = max(len(item) for item in lst)
    num_rows = math.ceil(len(lst) / num_columns)

    # Create a list of lists, where each sub-list is a column in the output
    columns = [lst[i : i + num_rows] for i in range(0, len(lst), num_rows)]

    # Pad each string in each column to the max length so they line up correctly
    for col in columns:
        for i in range(len(col)):
            col[i] = col[i].ljust(max_len)

    # Print each row
    for i in range(num_rows):
        for col in columns:
            if i < len(col):
                print(col[i], end=" ")
        print()


print_dir_style(methods, 5)
# Out:
# len(methods) = 72
# DISPLAY              dataframe2sasdata    list_tables          saslib               submit
# HTML                 datasets             logoffset            saslog               submitLOG
# HTML_Style           df2sd                nosub                sasml                submitLST
# SAS_EPOCH            df_char_lengths      pyenc                sasqc                symexist
# SASpid               dirlist              read_csv             sasstat              symget
# SYSERR               disconnect           reconuri             sasutil              symput
# SYSERRORTEXT         download             results              sasver               teach_me_SAS
# SYSFILRC             endsas               sas_date_fmts        sasviyaml            upload
# SYSINFO              exist                sas_datetime_fmts    sd2df                validvarname
# SYSLIBRC             file_copy            sas_time_fmts        sd2df_CSV            version
# ...

# %%
for libref in sas.assigned_librefs():
    print(libref)
# Out:
# WORK
# SASDATA
# STPSAMP
# SASHELP
# MAPS
# MAPSSAS
# MAPSGFK
# SASUSER

# %% [markdown]
# ### results

# %%
sas.results = "HTML"
sas.datasets("sasuser")
sas.results = "pandas"
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# ### prompt

# %%
# ps = """
# data cars;
#     set sashelp.cars;
# run;
# """
# ll = sas.submit(ps)

# %%
# ll = sas.submit(
#     'data &dsname; set sashelp.&from_tbl; run; proc print data=&dsname;run;',
#     prompt={"from_tbl": True, "dsname": True},
# )

# %%
# sas.HTML(ll["LST"])

# %%
# print(ll["LOG"])

# %% [markdown]
# ### saslog

# %%
print(f"{len(sas.saslog())=}")
print(sas.saslog())
# Out:
# len(sas.saslog())=4469
#
# 1                                                          The SAS System                          Tuesday, May  7, 2024 01:00:00 PM
#
#
#
#
# You are running SAS 9. Some SAS 8 files will be automatically converted
# by the V9 engine; others are incompatible.  Please see
# http://support.sas.com/rnd/migration/planning/platform/64bit.html
#
# PROC MIGRATE will preserve current SAS file attributes and is
# recommended for converting all your SAS libraries from any
# SAS 8 release to SAS 9.  For details and examples, please see
# http://support.sas.com/rnd/migration/index.html
#
#
# This message is contained in the SAS news file, and is presented upon
# initialization.  Edit the file "news" in the "misc/base" directory to
# display site-specific news and information in the program log.
# The command line option "-nonews" will prevent this display.
#
#
#
#
# 1          ;*';*";*/;
# ...

# %% [markdown]
# ### submit methods

# %%
sascode = """
data a;x=1;run; proc print data=a;run;
"""

# %%
sas.submit(sascode)
# Out:
# {'LOG': "\n9                                                          The SAS System                          Tuesday, May  7, 2024 01:00:00 PM\n\n54         ods listing close;ods html5 (id=saspy_internal) file=_tomods1 options(bitmap_mode='inline') device=svg style=Plateau; ods\n54       !  graphics on / outputfmt=png;\n55         \n56         \n57         data a;x=1;run;\n57       !                 proc print data=a;run;\n58         \n59         \n60         \n61         ods html5 (id=saspy_internal) close;ods listing;\n62         \n\n10                                                         The SAS System                          Tuesday, May  7, 2024 01:00:00 PM\n\n63         ",
# ...

# %%
sas.submitLST(sascode)
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
sas.submitLOG(sascode)
# Out:
# 13                                                         The SAS System                          Tuesday, May  7, 2024 01:00:00 PM
#
# 78         ods listing close;ods html5 (id=saspy_internal) file=_tomods1 options(bitmap_mode='inline') device=svg style=Plateau; ods
# 78       !  graphics on / outputfmt=png;
# 79
# 80
# 81         data a;x=1;run;
# 81       !                 proc print data=a;run;
# 82
# 83
# 84
# 85         ods html5 (id=saspy_internal) close;ods listing;
# 86
#
# 14                                                         The SAS System                          Tuesday, May  7, 2024 01:00:00 PM
#
# 87

# %%
sas.submitLST("data a;x=1;run; proc print data=a;run;", method="listorlog")
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
sas.sascfg.colorLOG
# Out:
# False

# %%
sas.submitLST("data a;x=1;run; proc print data=NoA;run;", method="listorlog")
# Out:
# 17                                                         The SAS System                          Tuesday, May  7, 2024 01:00:00 PM
#
# 100        ods listing close;ods html5 (id=saspy_internal) file=_tomods1 options(bitmap_mode='inline') device=svg style=Plateau; ods
# 100      !  graphics on / outputfmt=png;
# 101
# 102        data a;x=1;run;
# 102      !                 proc print data=NoA;run;
# ERROR: File WORK.NOA.DATA does not exist.
# 103
# 104
# 105        ods html5 (id=saspy_internal) close;ods listing;
# 106
#
# 18                                                         The SAS System                          Tuesday, May  7, 2024 01:00:00 PM
#
# 107
# c:\Users\yzdom\AppData\Local\Programs\Python\Python312\Lib\site-packages\saspy\sasioiom.py:1056: UserWarning: Noticed 'ERROR:' in LOG, you ought to take a look and see if there was a problem
#   warnings.warn("Noticed 'ERROR:' in LOG, you ought to take a look and see if there was a problem")

# %%
sas.submitLST("data a;x=1;run; proc print data=a;run;", method="listandlog")
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
sas.submitLST("data a;x=1;run; proc print data=a;run;", method="logandlist")
# Out:
# 21                                                         The SAS System                          Tuesday, May  7, 2024 01:00:00 PM
#
# 120        ods listing close;ods html5 (id=saspy_internal) file=_tomods1 options(bitmap_mode='inline') device=svg style=Plateau; ods
# 120      !  graphics on / outputfmt=png;
# 121
# 122        data a;x=1;run;
# 122      !                 proc print data=a;run;
# 123
# 124
# 125        ods html5 (id=saspy_internal) close;ods listing;
# 126
#
# 22                                                         The SAS System                          Tuesday, May  7, 2024 01:00:00 PM
#
# 127
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# ...
