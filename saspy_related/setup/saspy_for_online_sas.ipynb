# %% [markdown]
# ### Set up connection

# %%
# find out where the sascfg.py file is located
import saspy
from pathlib import Path
print(Path(saspy.SAScfg).as_posix())
# Out:
# c:/Users/yzdom/AppData/Local/Programs/Python/Python313/Lib/site-packages/saspy/sascfg.py

# %% [markdown]
# ### install java and place jar files

# %%
# install java: https://www.java.com/en/download/manual.jsp
# put the java path in the sascfg_personal.py file

# %%
# details see: https://sassoftware.github.io/saspy/configuration.html#sas-iom-client-encryption-jars
import saspy, os
print(saspy.__file__.replace('__init__.py', 'java%siomclient' % os.sep))

# %% [markdown]
# ### optionally make authinfo file for passwordless connection

# %%
# https://sassoftware.github.io/saspy/configuration.html#the-authinfo-file-authinfo-on-windows

# %% [markdown]
# ### optionally use raven style for dark vscode theme

# %%
SAS_output_options = {
    "output": "html5",  # not required unless changing any of the default
    # "style": "HTMLBlue",
    "style": "Raven",
}

# %% [markdown]
# ### optionally create personal saspy configuration file

# %%
# create the personal sascfg.py file
sascfg_personal = Path.home() / ".config" / "saspy" / "sascfg_personal.py"

# write the sascfg_personal.py file, create the directory if it does not exist
sascfg_personal.parent.mkdir(parents=True, exist_ok=True)

# copy the sascfg.py file to the sascfg_personal.py file
sascfg_personal.write_text(Path(saspy.SAScfg).read_text())

# print the location of the sascfg_personal.py file
print(sascfg_personal.as_posix())
# Out:
# C:/Users/yzdom/.config/saspy/sascfg_personal.py

# %% [markdown]
# ### test connection

# %%
import saspy
sas = saspy.SASsession()
# Out:
# Using SAS Config named: oda_euw1
# SAS Connection established. Subprocess id is 14160

# %%
sas
# Out:
# Access Method         = IOM
# SAS Config name       = oda_euw1
# SAS Config file       = c:\Users\yzdom\AppData\Local\Programs\Python\Python313\Lib\site-packages\saspy\sascfg.py
# WORK Path             = /saswork/SAS_work5A230001615B_odaws02-euw1.oda.sas.com/SAS_work27720001615B_odaws02-euw1.oda.sas.com/
# SAS Version           = 9.04.01M8P02222023
# SASPy Version         = 5.103.0
# Teach me SAS          = False
# Batch                 = False
# Results               = Pandas
# SAS Session Encoding  = utf-8
# Python Encoding value = utf-8
# SAS process Pid value = 90459
# SASsession started    = Sat Apr 18 00:28:16 2026

# %%
cars = sas.sasdata('cars', libref='sashelp')
cars.head()
# Out:
#     Make           Model   Type Origin DriveTrain     MSRP  Invoice  \
# 0  Acura             MDX    SUV   Asia        All  36945.0  33337.0
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  23820.0  21761.0
# 2  Acura         TSX 4dr  Sedan   Asia      Front  26990.0  24647.0
# 3  Acura          TL 4dr  Sedan   Asia      Front  33195.0  30299.0
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  43755.0  39014.0
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
sas.submitLST(
f"""
proc freq data=sashelp.cars;
    tables origin * type;
run;
""")
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...
