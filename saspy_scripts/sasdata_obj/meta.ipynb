# %%
import saspy
sas = saspy.SASsession(cfgname='oda')
# sas_html = saspy.SASsession(cfgname='oda', results='HTML')
# Out:
# SAS Connection established. Subprocess id is 9304

# %%
cars = sas.sasdata('cars', libref='sashelp')

# %%
cars.info()
# Out:
#        Type     Variable      N  Nmiss
# 0      char         Make  428.0    0.0
# 1      char        Model  428.0    0.0
# 2      char         Type  428.0    0.0
# 3      char       Origin  428.0    0.0
# 4      char   DriveTrain  428.0    0.0
# 5   numeric         MSRP  428.0    0.0
# 6   numeric      Invoice  428.0    0.0
# 7   numeric   EngineSize  428.0    0.0
# 8   numeric    Cylinders  428.0    2.0
# 9   numeric   Horsepower  428.0    0.0
# 10  numeric     MPG_City  428.0    0.0
# 11  numeric  MPG_Highway  428.0    0.0
# 12  numeric       Weight  428.0    0.0
# 13  numeric    Wheelbase  428.0    0.0
# 14  numeric       Length  428.0    0.0

# %%
cars.columnInfo()
# Out:
#           Member   Num     Variable  Type   Len    Pos    Format  \
# 0   SASHELP.CARS   9.0    Cylinders   Num   8.0   24.0       NaN
# 1   SASHELP.CARS   5.0   DriveTrain  Char   5.0  147.0       NaN
# 2   SASHELP.CARS   8.0   EngineSize   Num   8.0   16.0       NaN
# 3   SASHELP.CARS  10.0   Horsepower   Num   8.0   32.0       NaN
# 4   SASHELP.CARS   7.0      Invoice   Num   8.0    8.0  DOLLAR8.
# 5   SASHELP.CARS  15.0       Length   Num   8.0   72.0       NaN
# 6   SASHELP.CARS  11.0     MPG_City   Num   8.0   40.0       NaN
# 7   SASHELP.CARS  12.0  MPG_Highway   Num   8.0   48.0       NaN
# 8   SASHELP.CARS   6.0         MSRP   Num   8.0    0.0  DOLLAR8.
# 9   SASHELP.CARS   1.0         Make  Char  13.0   80.0       NaN
# 10  SASHELP.CARS   2.0        Model  Char  40.0   93.0       NaN
# 11  SASHELP.CARS   4.0       Origin  Char   6.0  141.0       NaN
# 12  SASHELP.CARS   3.0         Type  Char   8.0  133.0       NaN
# ...

# %%
res = cars.contents()
# Out:
# dict

# %%
res.keys()
# Out:
# dict_keys(['Attributes', 'Enginehost', 'Variables', 'Sortedby'])

# %%
res['Attributes']
# Out:
#          Member               Label1  \
# 0  SASHELP.CARS        Data Set Name
# 1  SASHELP.CARS          Member Type
# 2  SASHELP.CARS               Engine
# 3  SASHELP.CARS              Created
# 4  SASHELP.CARS        Last Modified
# 5  SASHELP.CARS           Protection
# 6  SASHELP.CARS        Data Set Type
# 7  SASHELP.CARS                Label
# 8  SASHELP.CARS  Data Representation
# 9  SASHELP.CARS             Encoding
#
#                                              cValue1       nValue1  \
# 0                                       SASHELP.CARS           NaN
# 1                                               DATA           NaN
# 2                                                 V9           NaN
# 3                                08/06/2020 01:11:21  1.912295e+09
# 4                                08/06/2020 01:11:21  1.912295e+09
# 5                                                NaN           NaN
# 6                                                NaN           NaN
# ...

# %%
res['Enginehost']
# Out:
#           Member                      Label1  \
# 0   SASHELP.CARS          Data Set Page Size
# 1   SASHELP.CARS    Number of Data Set Pages
# 2   SASHELP.CARS             First Data Page
# 3   SASHELP.CARS            Max Obs per Page
# 4   SASHELP.CARS      Obs in First Data Page
# 5   SASHELP.CARS  Number of Data Set Repairs
# 6   SASHELP.CARS                    Filename
# 7   SASHELP.CARS             Release Created
# 8   SASHELP.CARS                Host Created
# 9   SASHELP.CARS                Inode Number
# 10  SASHELP.CARS           Access Permission
# 11  SASHELP.CARS                  Owner Name
# 12  SASHELP.CARS                   File Size
# 13  SASHELP.CARS           File Size (bytes)
#
#                                               cValue1      nValue1
# 0                                               65536      65536.0
# 1                                                   2          2.0
# 2                                                   1          1.0
# ...

# %%
res['Variables']
# Out:
#           Member   Num     Variable  Type   Len    Pos    Format  \
# 0   SASHELP.CARS   9.0    Cylinders   Num   8.0   24.0       NaN
# 1   SASHELP.CARS   5.0   DriveTrain  Char   5.0  147.0       NaN
# 2   SASHELP.CARS   8.0   EngineSize   Num   8.0   16.0       NaN
# 3   SASHELP.CARS  10.0   Horsepower   Num   8.0   32.0       NaN
# 4   SASHELP.CARS   7.0      Invoice   Num   8.0    8.0  DOLLAR8.
# 5   SASHELP.CARS  15.0       Length   Num   8.0   72.0       NaN
# 6   SASHELP.CARS  11.0     MPG_City   Num   8.0   40.0       NaN
# 7   SASHELP.CARS  12.0  MPG_Highway   Num   8.0   48.0       NaN
# 8   SASHELP.CARS   6.0         MSRP   Num   8.0    0.0  DOLLAR8.
# 9   SASHELP.CARS   1.0         Make  Char  13.0   80.0       NaN
# 10  SASHELP.CARS   2.0        Model  Char  40.0   93.0       NaN
# 11  SASHELP.CARS   4.0       Origin  Char   6.0  141.0       NaN
# 12  SASHELP.CARS   3.0         Type  Char   8.0  133.0       NaN
# ...

# %%
res['Sortedby']
# Out:
#          Member         Label1    cValue1  nValue1
# 0  SASHELP.CARS       Sortedby  Make Type      NaN
# 1  SASHELP.CARS      Validated        YES      NaN
# 2  SASHELP.CARS  Character Set       ANSI      NaN

# %% [markdown]
# ### rename and delete

# %%
sas.submit("data wkcars; set sashelp.cars; run;")
wkcars = sas.sasdata('wkcars')
sas.sasdata('wkcars2').delete()
wkcars.rename("wkcars2")
wkcars.table
# Out:
# 39                                                         The SAS System                         Friday, April  5, 2024 10:55:00 AM
#
# 218
# 219        proc delete data=WORK.'wkcars2'n;run;
# 220
# 221
# 222
#
# 40                                                         The SAS System                         Friday, April  5, 2024 10:55:00 AM
#
# 223
#
# 45                                                         The SAS System                         Friday, April  5, 2024 10:55:00 AM
#
# 250
# 251        proc datasets dd=WORK nolist;
# 252        change 'wkcars'n = 'wkcars2'n;
# 253        run;
# 253      !     quit;
# 254
# 255
# 256
#
# 46                                                         The SAS System                         Friday, April  5, 2024 10:55:00 AM
#
# 257
# 'wkcars2'

# %% [markdown]
# ### set_results

# %%
cars.set_results("HTML")
cars.head()
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
cars.set_results("pandas")
cars.head()
# Out:
#     Make           Model   Type Origin DriveTrain     MSRP  Invoice  \
# 0  Acura             MDX    SUV   Asia        All  36945.0  33337.0
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  23820.0  21761.0
# 2  Acura         TSX 4dr  Sedan   Asia      Front  26990.0  24647.0
# 3  Acura          TL 4dr  Sedan   Asia      Front  33195.0  30299.0
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  43755.0  39014.0
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
cars.set_results("")
res = cars.head()
print(type(res))
res
# Out:
#                                                            The SAS System                     Friday, April  5, 2024 11:13:00 AM   3
#
#                                        Drive                   Engine                                 MPG_
#  Obs Make  Model          Type  Origin Train     MSRP  Invoice  Size  Cylinders Horsepower MPG_City Highway Weight Wheelbase Length
#
#    1 Acura MDX            SUV    Asia  All    $36,945  $33,337   3.5      6         265       17       23    4451     106      189
#    2 Acura RSX Type S 2dr Sedan  Asia  Front  $23,820  $21,761   2.0      4         200       24       31    2778     101      172
#    3 Acura TSX 4dr        Sedan  Asia  Front  $26,990  $24,647   2.4      4         200       22       29    3230     105      183
#    4 Acura TL 4dr         Sedan  Asia  Front  $33,195  $30,299   3.2      6         270       20       28    3575     108      186
# ...
