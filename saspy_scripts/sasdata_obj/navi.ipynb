# %%
import saspy
sas = saspy.SASsession(cfgname='oda')
# sas_html = saspy.SASsession(cfgname='oda', results='HTML')
# Out:
# SAS Connection established. Subprocess id is 2888

# %%
import pandas as pd
import numpy as np

# %%
cars = sas.sasdata('cars', libref='sashelp')

# %% [markdown]
# ### navigation

# %%
cars.obs()
# Out:
# 428

# %%
cars.head()
# Out:
#     Make           Model   Type Origin DriveTrain     MSRP  Invoice  \
# 0  Acura             MDX    SUV   Asia        All  36945.0  33337.0
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  23820.0  21761.0
# 2  Acura         TSX 4dr  Sedan   Asia      Front  26990.0  24647.0
# 3  Acura          TL 4dr  Sedan   Asia      Front  33195.0  30299.0
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  43755.0  39014.0
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
cars.tail()
# Out:
#     Make                    Model   Type  Origin DriveTrain     MSRP  Invoice  \
# 0  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  40565.0  38203.0
# 1  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  42565.0  40083.0
# 2  Volvo               S80 T6 4dr  Sedan  Europe      Front  45210.0  42573.0
# 3  Volvo                      V40  Wagon  Europe      Front  26135.0  24641.0
# 4  Volvo                     XC70  Wagon  Europe        All  35145.0  33112.0
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         2.4        5.0       197.0      21.0         28.0  3450.0
# 1         2.3        5.0       242.0      20.0         26.0  3450.0
# 2         2.9        6.0       268.0      19.0         26.0  3653.0
# 3         1.9        4.0       170.0      22.0         29.0  2822.0
# 4         2.5        5.0       208.0      20.0         27.0  3823.0
#
#    Wheelbase  Length
# 0      105.0   186.0
# 1      105.0   186.0
# 2      110.0   190.0
# 3      101.0   180.0
# 4      109.0   186.0

# %%
df = cars.head()
df[df.columns[:10]]
# Out:
#     Make           Model   Type Origin DriveTrain     MSRP  Invoice  \
# 0  Acura             MDX    SUV   Asia        All  36945.0  33337.0
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  23820.0  21761.0
# 2  Acura         TSX 4dr  Sedan   Asia      Front  26990.0  24647.0
# 3  Acura          TL 4dr  Sedan   Asia      Front  33195.0  30299.0
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  43755.0  39014.0
#
#    EngineSize  Cylinders  Horsepower
# 0         3.5        6.0       265.0
# 1         2.0        4.0       200.0
# 2         2.4        4.0       200.0
# 3         3.2        6.0       270.0
# 4         3.5        6.0       225.0

# %%
df[df.columns[10:20]]
# Out:
#    MPG_City  MPG_Highway  Weight  Wheelbase  Length
# 0      17.0         23.0  4451.0      106.0   189.0
# 1      24.0         31.0  2778.0      101.0   172.0
# 2      22.0         29.0  3230.0      105.0   183.0
# 3      20.0         28.0  3575.0      108.0   186.0
# 4      18.0         24.0  3880.0      115.0   197.0

# %%
df = cars.head()
print(df.iloc[0,:].to_string())
# Out:
# Make             Acura
# Model              MDX
# Type               SUV
# Origin            Asia
# DriveTrain         All
# MSRP           36945.0
# Invoice        33337.0
# EngineSize         3.5
# Cylinders          6.0
# Horsepower       265.0
# MPG_City          17.0
# MPG_Highway       23.0
# Weight          4451.0
# Wheelbase        106.0
# Length           189.0
